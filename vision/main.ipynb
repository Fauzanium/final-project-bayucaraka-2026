# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.7 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# Out:
#      <input type="file" id="files-63cc96da-d775-4230-8d75-f85506d6c56d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63cc96da-d775-4230-8d75-f85506d6c56d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !yolo detect train model=yolov8n.pt data=./model/yolov11/data.yaml epochs=150 imgsz=640
# Out:
# runs  sample_data  yolov8n.pt

# %%
# !yolo detect val model=runs/detect/train/weights/best.pt data=./model/yolov11/data.yaml
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 956, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py", line 76, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 144, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 283, in _load
#     self.model, self.ckpt = load_checkpoint(weights)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 1509, in load_checkpoint
# ...

# %%
# !yolo detect predict model=runs/detect/train/weights/best.pt source=./model/yolov11/data.yaml

# %%
# !yolo export model=runs/detect/train/weights/best.pt format=onnx

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO
model = YOLO("best.pt")
img = cv2.imread("./runs/detect/predict/images/IMG_20240917_143644.jpg")
results = model(img)
box = results[0].boxes.xyxy[0].cpu().numpy().astype(int)
x1, y1, x2, y2 = box
u = (x1+x2) / 2
v = (y1+y2) / 2
fx = 1000
fy = 1000
cx = img.shape[1] / 2
cy = img.shape[0] / 2
H = 1.0
x_norm = (u - cx) / fx
y_norm = (v - cy) / fy

X= x_norm * H
Y= y_norm * H
Z= 0

cv2.circle(img, (int(u), int(v)), 5, (0,0,255), -1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title(f"X={X:.2f}, Y={Y:.2f}, Z={Z:.2f}")
plt.axis("off")

# %%
import cv2
import numpy as np
from ultralytics import YOLO
model = YOLO("best.pt")
img = cv2.imread("./runs/detect/predict/images/IMG_20240917_143644.jpg")
results = model(img)
